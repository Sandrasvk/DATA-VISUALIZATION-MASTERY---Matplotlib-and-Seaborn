# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Basic Plot')
plt.show()

# %%
#subplot
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')  #linestain
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-')

# %%
fig = plt.figure() #empty canvas

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) #LEFT, BOTTOM, WIDTH, HEIGHT
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])
    
axes.plot(x, y, 'b')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('OOPS')

axes2.plot(y, x, 'r')
axes2.set_label('Y')
axes2.set_label('X')
axes2.set_title('Axes 2')
# Out:
# Text(0.5, 1.0, 'Axes 2')

# %%
#subplots

fig,axes = plt.subplots(nrows = 1, ncols = 2) #canvas set

# %%
fig,axes = plt.subplots() #canvas set
axes.plot(x, y, 'r')

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_title('title')

fig

# %%
fig,axes = plt.subplots(figsize = (8, 4))

axes.plot(x, y, 'r')

# %%
fig,axes = plt.subplots(figsize = (8, 4), dpi = 200)

axes.plot(x, y, 'r')

# %%
fig.savefig('filename.png')

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x**2, label = 'x**2')
ax.plot(x, x**3, label = 'x**3')

ax.legend(loc = 0)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x**2, color = 'blue')
ax.plot(x, x**3, color = '#ff00ff')

# %%
fig, ax = plt.subplots(figsize = (12,6))

ax.plot(x, x + 1, color = 'red', linewidth = 0.25)
ax.plot(x, x + 2, color = 'red', linewidth = 0.50)
ax.plot(x, x + 3, color = 'red', linewidth = 1.00)
ax.plot(x, x + 4, color = 'red', linewidth = 2.00)

ax.plot(x, x + 5, color = 'green', lw = 3, ls = '-')
ax.plot(x, x + 6, color = 'green', lw = 3, ls = '-.')
ax.plot(x, x + 7, color = 'green', lw = 3, ls = ':')

line, = ax.plot(x, x + 8, color = 'black', lw = 1.50)
line.set_dashes([5, 10, 15, 10])

ax.plot(x, x + 9, color = 'blue', lw = 3, ls = '-', marker = '+')
ax.plot(x, x + 10, color = 'blue', lw = 3, ls = '--', marker = 'o')
ax.plot(x, x + 11, color = 'blue', lw = 3, ls = '-', marker = 's')
ax.plot(x, x + 12, color = 'blue', lw = 3, ls = '--', marker = 1)

ax.plot(x, x + 13, color = 'purple', lw=1, ls ='-', marker = 's', markersize = 8, markerfacecolor = 'yellow', markeredgewidth = 3, markeredgecolor = 'green')

# %%
#plotrange
fig, axes = plt.subplots(1, 3, figsize = (12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title('default axes ranges')

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title('custom axes range')
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %%
#scattered plot
plt.scatter(x,y)

# %%
x = np.random.rand(500)
y = np.random.rand(500)
plt.scatter(x, y, c = 'green', alpha = 0.5)
plt.title('scatter plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
#HISTOGRAM
x = np.random.normal(170, 10, 250)
plt.hist(x)
# Out:
# (array([ 4., 11., 16., 36., 48., 50., 45., 18., 15.,  7.]),
#  array([143.85287994, 148.90870036, 153.96452079, 159.02034122,
#         164.07616164, 169.13198207, 174.1878025 , 179.24362292,
#         184.29944335, 189.35526378, 194.4110842 ]),
#  <BarContainer object of 10 artists>)

# %%
x = [21, 22, 23, 4, 5, 6, 77, 8, 9, 10, 31, 32, 33, 34, 35, 36, 37, 18, 49, 50, 100]
num_bins = 5
n,bins,patches = plt.hist(x, num_bins, facecolor = 'blue', alpha = 1)

# %%
#boxplot

import pandas as pd
df = pd.DataFrame(np.random.rand(10, 5),columns = ['A', 'B', 'C', 'D', 'E'])
df
# Out:
#           A         B         C         D         E
# 0  0.734554  0.064534  0.418227  0.535256  0.770326
# 1  0.476760  0.346622  0.750430  0.767266  0.518967
# 2  0.348881  0.187108  0.912653  0.344132  0.021987
# 3  0.252700  0.585562  0.610692  0.044179  0.254270
# 4  0.866752  0.950499  0.512520  0.358359  0.248034
# 5  0.931128  0.341038  0.775873  0.370619  0.260010
# 6  0.596891  0.492497  0.039900  0.765249  0.271967
# 7  0.611630  0.745913  0.259180  0.780766  0.200170
# 8  0.215594  0.526125  0.111864  0.324083  0.680873
# 9  0.227008  0.067627  0.239165  0.972435  0.166881

# %%
plt.boxplot(df)
plt.show()
